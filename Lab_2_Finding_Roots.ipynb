# %% [markdown]
# <a href="https://colab.research.google.com/github/nafis10670/IUB_CSE317-Labs/blob/main/Lab_2_Finding_Roots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ####1. Write the Python code to find the root of the
# function
# $$𝑓(𝑥) = 𝑒^𝑥 − 3𝑥 $$
# using Newton-Raphson method. Implement the steps below:
#
# a. Compute 𝑓′(𝑥) analytically.
#
# b. Select initial guess of the root and put it in 𝑥𝑜𝑙𝑑.
#
# c. Implement the Newton-Raphson update rule:
# $$𝑥_{𝑛𝑒𝑤} = 𝑥_{𝑜𝑙𝑑} \ – \frac{𝑓(𝑥_{old})}{𝑓’(𝑥_{𝑜𝑙𝑑})} $$
#
# i. You can use python function defintions to defines functions like
#
# ```
# def f(x):
#   return np.exp(x) - 3*x
# ```
# You can now use f(2) to compute function value at x = 2.
#
# d. Compute the approximate relative error at each step,
# $$𝜖_a = |
# \frac{𝑥_{𝑛𝑒𝑤}−𝑥_{𝑜𝑙𝑑}}{𝑥_{𝑛𝑒𝑤}}| * 100\%$$
#
# e. Plot the function and the estimated roots in the same graph.
#
# f. Stop when the approximate relative error is less than 0.001%.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# define f(x)

# define f'(x)

# analytically

# define error function

# main update loop
  # x update rule
  # print x, f(x), error per upate loop
  # loop until error% < 0.001

# %% [markdown]
# ###2. Newton-Raphson method using finite difference derivatives
# a. Define python functions for the following finite difference methods for computing gradients of any function **f**
#
# >i) Forward difference equation
# >$$f'(a) = \frac{f(a + h) - f(a)}{h}$$
# >ii) Backward difference equation
# >$$f'(a) = \frac{f(a) - f(a - h)}{h}$$
# >iii) Central difference equation
# >$$f'(a) = \frac{f(a + h) - f(a - h)}{2h}$$
#
# b. Implement Newton-Raphson method in python to compute roots using the finite difference derivative functions.
#
# The function should print x, f(x), error calculated per iteration as shown below.
#
# c. Use the newly defined Newton-Raphson function to calculate the roots for the following function:
# $$𝑓(𝑥) = 𝑒^𝑥 − 3𝑥 $$
# Compute roots using all 3 finite difference methods. Use initial guess of 1.
#
# d. Plot the estimates per iteration for all 3 finite difference methods in a single subplot.
#
# Also plot the main function in another subplot.
#
# Example figure given below.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def f(x):
  return np.exp(x) - 3*x

#forward difference 
def forward_df(f, x, h = 0.01):
    return (f(x + h) - f(x))/h

#backward difference 

#central difference

# nr method
def nr_root_estimation_fr(f,initial_guess, err_tolerance = 0.001):
  #initialize
  #update loop
  #print iterations
  #store and return x estimates
  print("implement me")

def nr_root_estimation_bk(f, f_dx, initial_guess, err_tolerance = 0.001):
  #initialize
  #update loop
  x_new  = x_old - f(x_old)/f_dx(x_old)
  #print iterations
  #store and return x estimates
  print("implement me")

def nr_root_estimation_central(f, initial_guess, err_tolerance = 0.001):
  #initialize
  #update loop
  #print iterations
  #store and return x estimates
  print("implement me")

# %% [markdown]
# ###3. Double differentiation
# >Second order forward derivative
# >$$ \ \ \ f''(x) = \frac{\frac{f(x+h+h)-f(x+h)}{h} - \frac{f(x+h)-f(x)}{h}}{h}$$
# <br>
# >$$  =>f''(x) = \frac{f(x + 2h) -2f(x+h) + f(x)}{h^2}$$
#
# a. Find Second order derivatives for central and backward methods.
#
# b. Define python functions to calculate second order derivatives using forward backward and central methods

# %% [markdown]
# ###4. Modified Newton-Raphson Method for root estimation
#
# For Modified-NR Method
#
# A function u(x) is defined as follows:
# $$ u(x) = \frac{f(x)}{f'(x)} $$
#
# x is updated using u(x) instead of f(x)
# $$ x_{n+1} = x_n - \frac{u(x)}{u'(x)} $$
#
# New derived update formula in terms of f(x) again:
#
# $$ x_{n+1} = x_n - \frac{f(x)f'(x)}{[f'(x)]^2 - f(x)f''(x)} $$
#
# a. Define python function for modified newton raphson method for computing roots. The function should print x estimates, f(x) and error for every iteration. Example table in figure below.
#
# b. Use the modified newton raphson method to find the root for the following function:
# $$ f(x) = (x-3)^3(x+1) $$
# Use initial guess of 0.
#
# c. Plot the estimates produced by NR method and the newly defined modified netwon raphson method in the same subplot.
#
# Plot the main function f(x) in a separate subplot.
#
# Example figure is provided below

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####5. Write the python code to find the (local) maxima point of the function
# $$𝑓(𝑥) = 2 sin(𝑥) − \frac{x^2}{10}$$
#
# At a point where **f(x)** is maximum,  $$f'(x) = 0$$
# Using Newton’s method. For the method implement the steps below:
#
# a. Compute **𝑓′(𝑥)** analytically
#
# b. Use NR-method defined above to help estimate the maxima
#
# c. Select initial guess of the maxima at 1.
#
# d. Plot the estimated maxima on a separate subplot.
#
# e. Print the x estimate f(x) and error for every iteration as shown below
#
# f. Plot the curves of f(x), f'(x) and the x-estimates per iteration as shown below

# %% [markdown]
# ![image.png](data:image/png;base64,...)
